# %%
from docx import Document
import pandas as pd

def merge_all_tables_to_dataframe(file_path):
    # Load the Word document
    doc = Document(file_path)
    
    # Initialize an empty list to store DataFrames
    all_tables = []
    
    # Loop through all tables in the document
    for table in doc.tables:
        # Extract data from the table
        data = []
        for row in table.rows:
            # Remove \n and strip each cell's text
            data.append([cell.text.replace('\n', ' ').strip() for cell in row.cells])
        
        # Convert the table data to a DataFrame
        df = pd.DataFrame(data)
        
        # Use the first row as the header if applicable
        df.columns = df.iloc[0]  # Set the first row as the header
        df = df[1:]  # Drop the header row from data
        
        # Append the DataFrame to the list
        all_tables.append(df)
    
    # Concatenate all DataFrames into a single DataFrame
    merged_df = pd.concat(all_tables, ignore_index=True)
    
    return merged_df

# Example Usage
file_path = r"D:\ProvenTech\Document_2_Test.docx"  # Replace with the path to your Word document
dtf = merge_all_tables_to_dataframe(file_path)

# %%
dtf.columns=["Sr.","Test","Specification","Reference"]
dtf
# Out:
#      Sr.                                               Test  \
# 0    1.0                                        Description
# 1    2.0                                         Solubility
# 2    3.0  A. Identification by IR      B. Identification...
# 3    4.0                                      Water Content
# 4    5.0                                Residue on ignition
# 5    6.0                                       Heavy metals
# 6    7.0  Tartaric acid content by  Titrimetry (on anhyd...
# 7    8.0  Organic Impurities Procedure-1  A. Phenol Impu...
# 8           Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 9    9.0                Assay by HPLC (on  anhydrous basis)
# 10  10.0  Residual solvents by GC A. n-Heptane B. Ethyl ...
# 11  11.0                                      Particle size
# 12  12.0                                      Melting Range
# 13  13.0  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                         Specification    Reference
# 0                          White to Off white powder.  Current USP
# 1   Very soluble in water and in methanol,  very s...  Current USP
# 2   A. The infrared absorption spectrum of  the sa...  Current USP
# 3                              Not more than 0.5% w/w  Current USP
# 4                             Not more than 0.10% w/w  Current USP
# 5                                Not more than 0.001%     In-House
# 6                          Between 36.4% to 38.3% w/w     In-Hosue
# 7   A. Not more than 0.10% B. Not more than 0.15% ...  Current USP
# 8                                 Not more than 0.15%  Current USP
# 9                             Between 98.0% to 102.0%  Current USP
# 10  A. Not more than 100 ppm B. Not more than 100 ...     In-House
# 11       10% particles should be not more than 10  µm     In-House
# 12  Between 121°C and 128°C (Melts within  a two-d...     In-House
# 13                            Between +5.0° and +6.5°     In-House

# %%
dtf["Sr."]=range(1, len(dtf) + 1)
dtf
# Out:
#     Sr.                                               Test  \
# 0     1                                        Description
# 1     2                                         Solubility
# 2     3  A. Identification by IR      B. Identification...
# 3     4                                      Water Content
# 4     5                                Residue on ignition
# 5     6                                       Heavy metals
# 6     7  Tartaric acid content by  Titrimetry (on anhyd...
# 7     8  Organic Impurities Procedure-1  A. Phenol Impu...
# 8     9    Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 9    10                Assay by HPLC (on  anhydrous basis)
# 10   11  Residual solvents by GC A. n-Heptane B. Ethyl ...
# 11   12                                      Particle size
# 12   13                                      Melting Range
# 13   14  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                         Specification    Reference
# 0                          White to Off white powder.  Current USP
# 1   Very soluble in water and in methanol,  very s...  Current USP
# 2   A. The infrared absorption spectrum of  the sa...  Current USP
# 3                              Not more than 0.5% w/w  Current USP
# 4                             Not more than 0.10% w/w  Current USP
# 5                                Not more than 0.001%     In-House
# 6                          Between 36.4% to 38.3% w/w     In-Hosue
# 7   A. Not more than 0.10% B. Not more than 0.15% ...  Current USP
# 8                                 Not more than 0.15%  Current USP
# 9                             Between 98.0% to 102.0%  Current USP
# 10  A. Not more than 100 ppm B. Not more than 100 ...     In-House
# 11       10% particles should be not more than 10  µm     In-House
# 12  Between 121°C and 128°C (Melts within  a two-d...     In-House
# 13                            Between +5.0° and +6.5°     In-House

# %%
SPEC_TABLE=dtf
SPEC_TABLE.to_csv("D:\ProvenTech\SPEC_TABLE_2.csv", index=False)

# %%
lst=df.iloc[2].tolist()
lst
# Out:
# ['3.0',
#  'A. Identification by IR      B. Identification by  HPLC',
#  'A. The infrared absorption spectrum of  the sample in a  potassium bromide  dispersion exhibits maxima only at the  same wavelengths  as that of a similar  preparation of  Rivastigmine tartrate  Reference  Standard or Working  Standard.  B. The retention time of the major peak  of the sample solution corresponds to that  of system suitability solution, as obtained  in the test for organic impurities,  Procedure-2.',
#  'Current USP']

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_groq import ChatGroq
llm = ChatGroq(
        model_name="llama-3.1-70b-versatile",
        temperature=0,
        groq_api_key="Your Groq API key"
    )
prompt_template = PromptTemplate.from_template(
    """You are an expert in deriving a list from another list based on given conditions.
    you are given a row of a dataframe in the form of list as input. the columns of this dataframe is [Sr., Test,Specification,Reference].
    you have to return a list so that I can append it to a new dataframe. the new dataframe columns are [TEST_NAME,SUB_TEST,TEXT_LIMIT,NLT(Not Less Than),NMT(Not More Than)]
    so keep in mind to return list of values in such a way that I can append to this dataframe.
    here are the conditions of convertion:
    TEST_NAME: This will be directly taken from the Test column in SPEC_TABLE.
    SUB_TEST: If a sub-test is present, populate this column with its name; otherwise, use the value from the Test column.
    TEXT_LIMIT: Extract this directly from the Specification column of SPEC_TABLE.
    NLT (Not Less Than): Extract this value from the Specification text where it states "not less than" and store it as a string.
    NMT (Not More Than): Similarly, extract this value where it states "not more than" and store it as a string.
    Handling "Between" Specifications:
    If the Specification mentions "between," you will encounter two values. Populate these values accordingly:
    The first value should be assigned to NLT,
    The second value should be assigned to NMT.
    If Specification value has more than one value then return those number of lists with seperated sub topics and mention those names in subtests.
    example for splitting: input:['8.0',
 'Organic Impurities Procedure-1  A. Phenol Impurity B. DPTTA C. Nor impurity D. Any other Impurity E. Total impurities',
 'A. Not more than 0.10% B. Not more than 0.15% C. Not more than 0.15% D. Not more than 0.10% E. Not more than 0.50%',
 'Current USP']
    output:[["Organic Impurities Procedure-1","Phenol Impurity","Not more than 0.10%","NLT extracted from specification","NMT extracted from specification"],
    ["Organic Impurities Procedure-1","DPTTA","Not more than 0.15%","NLT extracted from specification","NMT extracted from specification"],
    [same for c],[for D],[for E]]
    if NLT and NMT are not present just put None.
    input :{lst}
    output: only return list and nothing else.[] or [[],[],....]
    NO PREAMBLE
    return only list not code or any explanation
    """
)
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
columns = ["TEST_NAME", "SUB_TEST", "TEXT_LIMIT", "NLT (Not Less Than)", "NMT (Not More Than)"]
LIMITS = pd.DataFrame(columns=columns)

def append_to_dataframe(LIMITS, data):
    # Ensure data is a list of lists
    if isinstance(data[0], list):
        new_data = data  # Data is already a list of lists
    else:
        new_data = [data]  # Convert single row to a list of lists

    # Convert new data to a DataFrame and append
    new_df = pd.DataFrame(new_data, columns=LIMITS.columns)
    return pd.concat([LIMITS, new_df], ignore_index=True)

# %%
import ast
for index in range(len(SPEC_TABLE)):
    row = SPEC_TABLE.iloc[index].tolist()
    response = chain.run({"lst": row})
    actual_list = ast.literal_eval(response)
    LIMITS = append_to_dataframe(LIMITS, actual_list)

# %%
LIMITS
# Out:
#                                             TEST_NAME  \
# 0                                         Description
# 1                                          Solubility
# 2                                Identification by IR
# 3                              Identification by HPLC
# 4                                       Water Content
# 5                                 Residue on ignition
# 6                                        Heavy metals
# 7   Tartaric acid content by  Titrimetry (on anhyd...
# 8                      Organic Impurities Procedure-1
# 9                      Organic Impurities Procedure-1
# 10                     Organic Impurities Procedure-1
# 11                     Organic Impurities Procedure-1
# 12                     Organic Impurities Procedure-1
# 13    Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 14                Assay by HPLC (on  anhydrous basis)
# 15                            Residual solvents by GC
# 16                            Residual solvents by GC
# 17                            Residual solvents by GC
# 18                            Residual solvents by GC
# 19                            Residual solvents by GC
# 20                                      Particle size
# 21                                      Melting Range
# 22  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                              SUB_TEST  \
# 0                                         Description
# 1                                          Solubility
# 2                                Identification by IR
# 3                              Identification by HPLC
# 4                                       Water Content
# 5                                 Residue on ignition
# 6                                        Heavy metals
# 7   Tartaric acid content by  Titrimetry (on anhyd...
# 8                                     Phenol Impurity
# 9                                               DPTTA
# 10                                       Nor impurity
# 11                                 Any other Impurity
# 12                                   Total impurities
# 13    Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 14                Assay by HPLC (on  anhydrous basis)
# 15                                          n-Heptane
# 16                                      Ethyl acetate
# 17                                           Methanol
# 18                                    Dichloromethane
# 19                                  Isopropyl alcohol
# 20                                      Particle size
# 21                                      Melting Range
# 22  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                            TEXT_LIMIT NLT (Not Less Than)  \
# 0                          White to Off white powder.                None
# 1   Very soluble in water and in methanol,  very s...                None
# 2                                                None                None
# 3                                                None                None
# 4                              Not more than 0.5% w/w                None
# 5                             Not more than 0.10% w/w                None
# 6                                Not more than 0.001%                None
# 7                          Between 36.4% to 38.3% w/w           36.4% w/w
# 8                                 Not more than 0.10%                None
# 9                                 Not more than 0.15%                None
# 10                                Not more than 0.15%                None
# 11                                Not more than 0.10%                None
# 12                                Not more than 0.50%                None
# 13                                Not more than 0.15%                None
# 14                            Between 98.0% to 102.0%               98.0%
# 15                              Not more than 100 ppm                None
# 16                              Not more than 100 ppm                None
# 17                              Not more than 200 ppm                None
# 18                              Not more than 100 ppm                None
# 19                              Not more than 500 ppm                None
# 20       10% particles should be not more than 10  µm                None
# 21  Between 121°C and 128°C (Melts within  a two-d...               121°C
# 22                            Between +5.0° and +6.5°               +5.0°
#
#       NMT (Not More Than)
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                0.5% w/w
# 5                   0.10%
# 6                  0.001%
# 7               38.3% w/w
# 8                   0.10%
# 9                   0.15%
# 10                  0.15%
# 11                  0.10%
# 12                  0.50%
# 13                  0.15%
# 14                 102.0%
# 15  Not more than 100 ppm
# 16  Not more than 100 ppm
# 17  Not more than 200 ppm
# 18  Not more than 100 ppm
# 19  Not more than 500 ppm
# 20                  10 µm
# 21                  128°C
# 22                  +6.5°

# %%
LIMITS.to_csv("D:\ProvenTech\LIMITS_2.csv", index=False)

# %%
SPEC_TABLE
# Out:
#     Sr.                                               Test  \
# 0     1                                        Description
# 1     2                                         Solubility
# 2     3  A. Identification by IR      B. Identification...
# 3     4                                      Water Content
# 4     5                                Residue on ignition
# 5     6                                       Heavy metals
# 6     7  Tartaric acid content by  Titrimetry (on anhyd...
# 7     8  Organic Impurities Procedure-1  A. Phenol Impu...
# 8     9    Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 9    10                Assay by HPLC (on  anhydrous basis)
# 10   11  Residual solvents by GC A. n-Heptane B. Ethyl ...
# 11   12                                      Particle size
# 12   13                                      Melting Range
# 13   14  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                         Specification    Reference
# 0                          White to Off white powder.  Current USP
# 1   Very soluble in water and in methanol,  very s...  Current USP
# 2   A. The infrared absorption spectrum of  the sa...  Current USP
# 3                              Not more than 0.5% w/w  Current USP
# 4                             Not more than 0.10% w/w  Current USP
# 5                                Not more than 0.001%     In-House
# 6                          Between 36.4% to 38.3% w/w     In-Hosue
# 7   A. Not more than 0.10% B. Not more than 0.15% ...  Current USP
# 8                                 Not more than 0.15%  Current USP
# 9                             Between 98.0% to 102.0%  Current USP
# 10  A. Not more than 100 ppm B. Not more than 100 ...     In-House
# 11       10% particles should be not more than 10  µm     In-House
# 12  Between 121°C and 128°C (Melts within  a two-d...     In-House
# 13                            Between +5.0° and +6.5°     In-House

# %%
LIMITS
# Out:
#                                             TEST_NAME  \
# 0                                         Description
# 1                                          Solubility
# 2                                Identification by IR
# 3                              Identification by HPLC
# 4                                       Water Content
# 5                                 Residue on ignition
# 6                                        Heavy metals
# 7   Tartaric acid content by  Titrimetry (on anhyd...
# 8                      Organic Impurities Procedure-1
# 9                      Organic Impurities Procedure-1
# 10                     Organic Impurities Procedure-1
# 11                     Organic Impurities Procedure-1
# 12                     Organic Impurities Procedure-1
# 13    Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 14                Assay by HPLC (on  anhydrous basis)
# 15                            Residual solvents by GC
# 16                            Residual solvents by GC
# 17                            Residual solvents by GC
# 18                            Residual solvents by GC
# 19                            Residual solvents by GC
# 20                                      Particle size
# 21                                      Melting Range
# 22  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                              SUB_TEST  \
# 0                                         Description
# 1                                          Solubility
# 2                                Identification by IR
# 3                              Identification by HPLC
# 4                                       Water Content
# 5                                 Residue on ignition
# 6                                        Heavy metals
# 7   Tartaric acid content by  Titrimetry (on anhyd...
# 8                                     Phenol Impurity
# 9                                               DPTTA
# 10                                       Nor impurity
# 11                                 Any other Impurity
# 12                                   Total impurities
# 13    Procedure-2 (Enantiomeric Purity)  R-Enantiomer
# 14                Assay by HPLC (on  anhydrous basis)
# 15                                          n-Heptane
# 16                                      Ethyl acetate
# 17                                           Methanol
# 18                                    Dichloromethane
# 19                                  Isopropyl alcohol
# 20                                      Particle size
# 21                                      Melting Range
# 22  Specific optical Rotation (5% w/v in Ethanol a...
#
#                                            TEXT_LIMIT NLT (Not Less Than)  \
# 0                          White to Off white powder.                None
# 1   Very soluble in water and in methanol,  very s...                None
# 2                                                None                None
# 3                                                None                None
# 4                              Not more than 0.5% w/w                None
# 5                             Not more than 0.10% w/w                None
# 6                                Not more than 0.001%                None
# 7                          Between 36.4% to 38.3% w/w           36.4% w/w
# 8                                 Not more than 0.10%                None
# 9                                 Not more than 0.15%                None
# 10                                Not more than 0.15%                None
# 11                                Not more than 0.10%                None
# 12                                Not more than 0.50%                None
# 13                                Not more than 0.15%                None
# 14                            Between 98.0% to 102.0%               98.0%
# 15                              Not more than 100 ppm                None
# 16                              Not more than 100 ppm                None
# 17                              Not more than 200 ppm                None
# 18                              Not more than 100 ppm                None
# 19                              Not more than 500 ppm                None
# 20       10% particles should be not more than 10  µm                None
# 21  Between 121°C and 128°C (Melts within  a two-d...               121°C
# 22                            Between +5.0° and +6.5°               +5.0°
#
#       NMT (Not More Than)
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                0.5% w/w
# 5                   0.10%
# 6                  0.001%
# 7               38.3% w/w
# 8                   0.10%
# 9                   0.15%
# 10                  0.15%
# 11                  0.10%
# 12                  0.50%
# 13                  0.15%
# 14                 102.0%
# 15  Not more than 100 ppm
# 16  Not more than 100 ppm
# 17  Not more than 200 ppm
# 18  Not more than 100 ppm
# 19  Not more than 500 ppm
# 20                  10 µm
# 21                  128°C
# 22                  +6.5°
